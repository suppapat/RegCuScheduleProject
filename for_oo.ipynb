# %%
import requests

# %%
url_head = 'https://cas.reg.chula.ac.th/servlet/com.dtm.chula.cs.servlet.QueryCourseScheduleNew.QueryCourseScheduleNewServlet'
cook=requests.get(url_head,verify=False)
cookies_head=cook.cookies

url_left="https://cas.reg.chula.ac.th/servlet/com.dtm.chula.cs.servlet.QueryCourseScheduleNew.CourseListNewServlet?examdateCombo=I2017207/05/1475&studyProgram=S&semester=2&acadyearEfd=2561&submit.x=0&submit.y=0&courseno=23&coursename=&examdate=&examstartshow=&examendshow=&faculty=23&coursetype=&genedcode=&cursemester=1&curacadyear=2561&examstart=&examend=&activestatus=OFF&acadyear=2561&lang=T&download=download"
result_left=requests.get(url_left,verify=False,cookies=cookies_head)
url_cen="https://cas.reg.chula.ac.th/servlet/com.dtm.chula.cs.servlet.QueryCourseScheduleNew.CourseScheduleDtlNewServlet?courseNo=2300200&studyProgram=S"
result_center=requests.get(url_cen,verify=False,cookies=cookies_head)
# Out:
# C:\Users\suppa\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\suppa\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\suppa\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#print(result_left.text)

# %%
print(result_center.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 FINAL//EN">
#
# <HTML>
# <HEAD>
# <META HTTP-EQUIV="Content-Type" CONTENT="text/html; ">
# <META NAME="Generator" CONTENT="NetObjects Fusion 4.0 for Windows">
# <TITLE>CourseGroupDetail</TITLE>
# <script type="text/javascript">
# function reset() {
# 	if (parent.frames.length == 3) {
# 		parent.frames[1].document.forms[0].activestatus.value = "ON";
# 	}
# }
# function verify(){
# 	if (document.forms[0].activestatus.value == "ON")	{
# 		document.forms[0].activestatus.value = "OFF";
# 		return true;
# 	} else {
# 		alert("��س����ѡ���� !");
# 		return false;
# 	}
# }
# </script>
# </HEAD>
# <BODY BGCOLOR="#FFFFFF"  LINK="#0000FF" VLINK="#800080" TEXT="#000000" TOPMARGIN=0 LEFTMARGIN=0 MARGINWIDTH=0 MARGINHEIGHT=0 Onload="reset();">
#
#
#
#
#
#
# <FORM NAME="courseScheduleDtlForm" method="post">
#
# 	<TABLE ID="dw" ALIGN=CENTER BORDER=0 width="100%">
# 		<TR ALIGN=CENTER>
#
# 			<TD></TD>
#
# 		</TR>
# 	</TABLE>
# ...

# %%
url_head = 'https://cas.reg.chula.ac.th/servlet/com.dtm.chula.cs.servlet.QueryCourseScheduleNew.QueryCourseScheduleNewServlet'
cook=requests.get(url_head,verify=False)
print(cook.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=0000PRV9tjOhcO7WpQP5H-njSPh:-1 for cas.reg.chula.ac.th/>, <Cookie NSC_WBqqSfhDmbttTTM=ffffffffc3a014d445525d5f4f58455e445a4a421548 for cas.reg.chula.ac.th/>]>
# C:\Users\suppa\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#url = 'https://cas.reg.chula.ac.th/servlet/com.dtm.chula.cs.servlet.QueryCourseScheduleNew.QueryCourseScheduleNewServlet'
#cookies = dict(cookies_are='working')
#r = requests.get(url, cookies=cookies_head)
